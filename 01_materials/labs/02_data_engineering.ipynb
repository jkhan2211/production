# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account.
#
# Extract all files into the directory: `./05_src/data/prices_csv/`
#
# Your folder structure should include the following paths:
#
# + `05_src/data/prices_csv/etfs`
# + `05_src/data/prices_csv/stocks`

# %%
import pandas as pd
import os
import sys
from glob import glob

sys.path.append(os.getenv('SRC_DIR'))

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to load the historical price data for stocks and ETFs, we could use:

# %%
import random

stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))

random.seed(42)
stock_files = random.sample(stock_files, 60)

dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2025-09-28 09:37:50,000, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TDACU.csv
# 2025-09-28 09:37:50,120, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LGF.B.csv
# 2025-09-28 09:37:50,128, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NEPT.csv
# 2025-09-28 09:37:50,146, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ASA.csv
# 2025-09-28 09:37:50,168, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RRBI.csv
# 2025-09-28 09:37:50,175, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AUTL.csv
# 2025-09-28 09:37:50,181, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FPI.csv
# 2025-09-28 09:37:50,189, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NEOG.csv
# 2025-09-28 09:37:50,207, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ASNA.csv
# 2025-09-28 09:37:50,223, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CBLI.csv
# 2025-09-28 09:37:50,235, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/OIS.csv
# 2025-09-28 09:37:50,248, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EDRY.csv
# 2025-09-28 09:37:50,253, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JP.csv
# 2025-09-28 09:37:50,260, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/OI.csv
# 2025-09-28 09:37:50,277, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VXZ.csv
# 2025-09-28 09:37:50,286, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VTSI.csv
# 2025-09-28 09:37:50,293, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VSTO.csv
# 2025-09-28 09:37:50,298, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AXSM.csv
# 2025-09-28 09:37:50,307, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ITRI.csv
# 2025-09-28 09:37:50,321, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BK.csv
# 2025-09-28 09:37:50,348, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LOGI.csv
# 2025-09-28 09:37:50,362, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AOBC.csv
# 2025-09-28 09:37:50,375, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ACBI.csv
# 2025-09-28 09:37:50,381, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RCKY.csv
# 2025-09-28 09:37:50,397, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RCM.csv
# 2025-09-28 09:37:50,402, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NEXT.csv
# 2025-09-28 09:37:50,411, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LEVI.csv
# 2025-09-28 09:37:50,416, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CFFA.csv
# 2025-09-28 09:37:50,420, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CPRX.csv
# 2025-09-28 09:37:50,429, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ITT.csv
# 2025-09-28 09:37:50,441, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/XENE.csv
# 2025-09-28 09:37:50,450, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ALL.csv
# 2025-09-28 09:37:50,466, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TSN.csv
# 2025-09-28 09:37:50,497, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AFYA.csv
# 2025-09-28 09:37:50,506, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DCO.csv
# 2025-09-28 09:37:50,525, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LILA.csv
# 2025-09-28 09:37:50,533, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IBKR.csv
# 2025-09-28 09:37:50,543, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TXT.csv
# 2025-09-28 09:37:50,560, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TTEC.csv
# 2025-09-28 09:37:50,571, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PKI.csv
# 2025-09-28 09:37:50,588, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UA.csv
# 2025-09-28 09:37:50,593, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMS.csv
# 2025-09-28 09:37:50,613, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PNR.csv
# 2025-09-28 09:37:50,637, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CLGN.csv
# 2025-09-28 09:37:50,642, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DRIO.csv
# 2025-09-28 09:37:50,655, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ASRT.csv
# 2025-09-28 09:37:50,701, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RVSB.csv
# 2025-09-28 09:37:50,732, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RDUS.csv
# 2025-09-28 09:37:50,742, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SPXX.csv
# 2025-09-28 09:37:50,758, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RAIL.csv
# 2025-09-28 09:37:50,771, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SLAB.csv
# 2025-09-28 09:37:50,782, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MYO.csv
# 2025-09-28 09:37:50,787, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LW.csv
# 2025-09-28 09:37:50,795, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CSWCL.csv
# 2025-09-28 09:37:50,801, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RMAX.csv
# 2025-09-28 09:37:50,809, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GD.csv
# 2025-09-28 09:37:50,837, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LXFR.csv
# 2025-09-28 09:37:50,846, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MSA.csv
# 2025-09-28 09:37:50,865, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ORCC.csv
# 2025-09-28 09:37:50,870, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SMMT.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253164 entries, 0 to 253163
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       253164 non-null  datetime64[ns]
#  1   Open       253162 non-null  float64
#  2   High       253162 non-null  float64
#  3   Low        253162 non-null  float64
#  4   Close      253162 non-null  float64
#  5   Adj Close  253162 non-null  float64
#  6   Volume     253162 non-null  float64
#  7   source     253164 non-null  object
#  8   ticker     253164 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 17.4+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['TDACU',
#  'LGF.B',
#  'NEPT',
#  'ASA',
#  'RRBI',
#  'AUTL',
#  'FPI',
#  'NEOG',
#  'ASNA',
#  'CBLI',
#  'OIS',
#  'EDRY',
#  'JP',
#  'OI',
#  'VXZ',
#  'VTSI',
#  'VSTO',
#  'AXSM',
#  'ITRI',
#  'BK',
#  'LOGI',
#  'AOBC',
#  'ACBI',
#  'RCKY',
#  'RCM',
#  'NEXT',
#  'LEVI',
#  'CFFA',
#  'CPRX',
#  'ITT',
#  'XENE',
#  'ALL',
#  'TSN',
#  'AFYA',
#  'DCO',
#  'LILA',
#  'IBKR',
#  'TXT',
#  'TTEC',
#  'PKI',
#  'UA',
#  'AMS',
#  'PNR',
#  'CLGN',
#  'DRIO',
#  'ASRT',
#  'RVSB',
#  'RDUS',
#  'SPXX',
#  'RAIL',
#  'SLAB',
#  'MYO',
#  'LW',
#  'CSWCL',
#  'RMAX',
#  'GD',
#  'LXFR',
#  'MSA',
#  'ORCC',
#  'SMMT']

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
import shutil

# %%
temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")
shutil.rmtree(csv_dir, ignore_errors=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")
os.makedirs(csv_dir, exist_ok=True)

# %%
start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2025-09-28 09:38:25,782, 473192941.py, 5, INFO, Writing data ((253164, 9)) to csv took 1.9730453491210938 seconds.
# 2025-09-28 09:38:25,785, 473192941.py, 6, INFO, CSV file size 28.177930999999997 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
# !pip install --upgrade dask pyarrow fastparquet pandas

px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# Requirement already satisfied: dask in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (2024.8.0)
# Requirement already satisfied: pyarrow in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (19.0.0)
# Collecting pyarrow
#   Downloading pyarrow-21.0.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (2.3.1)
# Collecting pandas
#   Downloading pandas-2.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: click>=8.1 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (8.1.8)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (2025.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from dask) (8.7.0)
# Requirement already satisfied: numpy in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from fastparquet) (2.0.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: zipp>=3.20 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask) (3.23.0)
# Requirement already satisfied: locket in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from partd>=1.4.0->dask) (1.0.0)
# Requirement already satisfied: six>=1.5 in /home/junaidkhandsi/miniconda3/envs/dsi_participant/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pyarrow-21.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (42.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 MB 667.6 kB/s eta 0:00:0000:0100:02
# Downloading fastparquet-2024.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 773.4 kB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 725.5 kB/s eta 0:00:0000:0100:01
# Downloading cramjam-2.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 658.2 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyarrow, cramjam, pandas, fastparquet
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 19.0.0
#     Uninstalling pyarrow-19.0.0:
#       Successfully uninstalled pyarrow-19.0.0
#   Attempting uninstall: pandas━━━━━━━━━━━━━━━━━━ 0/4 [pyarrow]
#     Found existing installation: pandas 2.3.1 0/4 [pyarrow]
#     Uninstalling pandas-2.3.1:0m╺━━━━━━━━━━━━━━━━━━━ 2/4 [pandas]
#       Successfully uninstalled pandas-2.3.1━━━━━━━━━━━━━━━━━━━ 2/4 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [fastparquet] [fastparquet]
# Successfully installed cramjam-2.11.0 fastparquet-2024.11.0 pandas-2.3.2 pyarrow-21.0.0
# 2025-09-28 13:38:21,789, 1725370540.py, 9, INFO, Writing dd ((253164, 9)) to parquet took 0.9854912757873535 seconds.
# 2025-09-28 13:38:21,793, 1725370540.py, 10, INFO, Parquet file size 10.033444 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# /tmp/ipykernel_237828/102405636.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year Close_lag_1  Returns
# npartitions=60
# ACBI            datetime64[ns]  float64  float64  float64  float64   float64  float64  object  int32     float64  float64
# AFYA                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# XENE                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# XENE                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# Dask Name: assign, 14 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date    Open    High    Low   Close  Adj Close    Volume  \
# ticker
# ACBI   2015-11-02  13.800  15.000  13.80  15.000     15.000    1700.0
# ACBI   2015-11-03  17.500  17.500  15.66  15.660     15.660    3800.0
# ACBI   2015-11-04  15.001  15.050  14.30  14.305     14.305   76400.0
# ACBI   2015-11-05  14.300  14.500  13.99  14.050     14.050  147000.0
# ACBI   2015-11-06  14.160  14.205  14.07  14.150     14.150   51200.0
# ...           ...     ...     ...    ...     ...        ...       ...
# XENE   2020-03-26  11.280  11.970  10.64  11.450     11.450  688600.0
# XENE   2020-03-27  11.040  11.300  10.51  11.000     11.000  149400.0
# XENE   2020-03-30  10.940  11.190  10.60  10.960     10.960  226800.0
# XENE   2020-03-31  10.960  11.600  10.69  11.340     11.340  184100.0
# XENE   2020-04-01  11.020  11.270  10.13  10.210     10.210  739700.0
#
#           source  Year  Close_lag_1   Returns
# ticker
# ACBI    ACBI.csv  2015          NaN       NaN
# ACBI    ACBI.csv  2015       15.000  0.044000
# ACBI    ACBI.csv  2015       15.660 -0.086526
# ACBI    ACBI.csv  2015       14.305 -0.017826
# ACBI    ACBI.csv  2015       14.050  0.007117
# ...          ...   ...          ...       ...
# XENE    XENE.csv  2020       11.250  0.017778
# XENE    XENE.csv  2020       11.450 -0.039301
# XENE    XENE.csv  2020       11.000 -0.003636
# XENE    XENE.csv  2020       10.960  0.034672
# XENE    XENE.csv  2020       11.340 -0.099647
#
# [253164 rows x 11 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2025-09-28 13:39:42,304, data_manager.py, 53, INFO, Processing sample of tickers
# 2025-09-28 13:39:42,312, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2025-09-28 13:39:42,347, data_manager.py, 66, INFO, Found 8050 files in ../../05_src/data/prices/
# 2025-09-28 13:39:42,348, data_manager.py, 74, INFO, Selecting sample of files
# 2025-09-28 13:39:42,349, data_manager.py, 80, INFO, Selected 30 files
# 2025-09-28 13:39:42,349, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/PERI.csv
# 2025-09-28 13:39:42,350, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PERI.csv
# 2025-09-28 13:39:42,370, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:42,679, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/FMNB.csv
# 2025-09-28 13:39:42,680, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FMNB.csv
# 2025-09-28 13:39:42,693, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:43,096, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/POPE.csv
# 2025-09-28 13:39:43,097, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/POPE.csv
# 2025-09-28 13:39:43,114, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:43,771, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/RYH.csv
# 2025-09-28 13:39:43,772, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/RYH.csv
# 2025-09-28 13:39:43,781, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:44,079, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/RARX.csv
# 2025-09-28 13:39:44,080, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RARX.csv
# 2025-09-28 13:39:44,087, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:44,183, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/EWSC.csv
# 2025-09-28 13:39:44,184, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/EWSC.csv
# 2025-09-28 13:39:44,194, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:44,395, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/PBH.csv
# 2025-09-28 13:39:44,397, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PBH.csv
# 2025-09-28 13:39:44,407, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:44,792, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/YGYI.csv
# 2025-09-28 13:39:44,793, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/YGYI.csv
# 2025-09-28 13:39:44,800, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:44,966, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/NTR.csv
# 2025-09-28 13:39:44,967, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NTR.csv
# 2025-09-28 13:39:44,973, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:45,237, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/FCAN.csv
# 2025-09-28 13:39:45,239, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/FCAN.csv
# 2025-09-28 13:39:45,248, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:45,437, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/DVN.csv
# 2025-09-28 13:39:45,438, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DVN.csv
# 2025-09-28 13:39:45,457, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:46,132, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/VSLR.csv
# 2025-09-28 13:39:46,133, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VSLR.csv
# 2025-09-28 13:39:46,141, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:46,270, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/KRG.csv
# 2025-09-28 13:39:46,272, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KRG.csv
# 2025-09-28 13:39:46,282, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:46,590, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/RETO.csv
# 2025-09-28 13:39:46,590, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RETO.csv
# 2025-09-28 13:39:46,597, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:46,678, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/SEF.csv
# 2025-09-28 13:39:46,679, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/SEF.csv
# 2025-09-28 13:39:46,687, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:46,936, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/BMEZ.csv
# 2025-09-28 13:39:46,937, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BMEZ.csv
# 2025-09-28 13:39:46,942, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:46,963, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/GRAF.csv
# 2025-09-28 13:39:46,964, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GRAF.csv
# 2025-09-28 13:39:46,973, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:47,578, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/ARDX.csv
# 2025-09-28 13:39:47,579, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ARDX.csv
# 2025-09-28 13:39:47,590, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:47,776, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/MARPS.csv
# 2025-09-28 13:39:47,777, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MARPS.csv
# 2025-09-28 13:39:47,792, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:48,586, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/YLCO.csv
# 2025-09-28 13:39:48,588, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/YLCO.csv
# 2025-09-28 13:39:48,595, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:48,709, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/NATH.csv
# 2025-09-28 13:39:48,710, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NATH.csv
# 2025-09-28 13:39:48,722, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:49,238, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/CIICU.csv
# 2025-09-28 13:39:49,239, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CIICU.csv
# 2025-09-28 13:39:49,245, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:49,285, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/BFK.csv
# 2025-09-28 13:39:49,286, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BFK.csv
# 2025-09-28 13:39:49,296, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:49,685, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/BABA.csv
# 2025-09-28 13:39:49,686, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BABA.csv
# 2025-09-28 13:39:49,693, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:49,824, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/STAG.csv
# 2025-09-28 13:39:49,826, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/STAG.csv
# 2025-09-28 13:39:49,834, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:50,030, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/TWOU.csv
# 2025-09-28 13:39:50,031, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TWOU.csv
# 2025-09-28 13:39:50,037, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:50,164, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/VEEV.csv
# 2025-09-28 13:39:50,165, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VEEV.csv
# 2025-09-28 13:39:50,173, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:50,326, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/CIEN.csv
# 2025-09-28 13:39:50,327, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CIEN.csv
# 2025-09-28 13:39:50,338, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:50,827, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/LBRDK.csv
# 2025-09-28 13:39:50,828, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LBRDK.csv
# 2025-09-28 13:39:50,834, data_manager.py, 101, INFO, Saving data by year
# 2025-09-28 13:39:50,966, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/MIST.csv
# 2025-09-28 13:39:50,967, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MIST.csv
# 2025-09-28 13:39:50,972, data_manager.py, 101, INFO, Saving data by year

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-09-28 13:39:51,021, data_manager.py, 131, INFO, Creating features data.
# 2025-09-28 13:39:51,023, data_manager.py, 141, INFO, Loading price data from ../../05_src/data/prices/
# 2025-09-28 13:40:28,607, data_manager.py, 150, INFO, Creating features
# /home/junaidkhandsi/dsi/assignments/production_ml/production/01_materials/labs/../../05_src/stock_prices/data_manager.py:153: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('ticker', group_keys=False)
# 2025-09-28 13:40:28,616, data_manager.py, 175, INFO, Saving features to ../../05_src/data/features/stock_features
